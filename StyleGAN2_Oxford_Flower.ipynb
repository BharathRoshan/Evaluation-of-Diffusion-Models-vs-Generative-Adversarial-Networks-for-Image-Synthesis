# %% [markdown]
# <a href="https://colab.research.google.com/github/BharathRoshan/Evaluation-of-Diffusion-Models-vs-Generative-Adversarial-Networks-for-Image-Synthesis/blob/main/StyleGAN2_Oxford_Flower.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install pytorch-fid
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pytorch-fid: filename=pytorch_fid-0.2.1-py3-none-any.whl size=14835 sha256=bf2a6cddccf0a81f18797822f61ec7125ac4b6abc03b7a8b99cf0a1dd2d2534d
#   Stored in directory: /root/.cache/pip/wheels/24/ac/03/c5634775c8a64f702343ef5923278f8d3bb8c651debc4a6890
# Successfully built pytorch-fid
# ...

# %%
# !pip install stylegan2_pytorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.4 MB 5.1 MB/s
# ...
#      |████████████████████████████████| 517 kB 54.4 MB/s
# ...
#      |████████████████████████████████| 87 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 18.6 MB 49.6 MB/s
# ...
#      |████████████████████████████████| 281 kB 65.4 MB/s
# ...
#      |████████████████████████████████| 55 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 209 kB 70.4 MB/s
# ...
#      |████████████████████████████████| 51 kB 387 kB/s
# ...
#      |████████████████████████████████| 3.1 MB 56.4 MB/s
# ...
#      |████████████████████████████████| 57 kB 4.9 MB/s
# ...
#      |████████████████████████████████| 4.1 MB 60.7 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 55.0 MB/s
# ...
#      |████████████████████████████████| 6.1 MB 48.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.8 MB/s
# ...
#      |████████████████████████████████| 60 kB 8.1 MB/s
# ...

# %%
from torchvision.transforms.transforms import Resize
from torch.utils.data import DataLoader
from torchvision.datasets import Flowers102
from torchvision import transforms
def flowerdata(batch_size):
  transform=transforms.Compose([
            transforms.Resize((32,32)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
        ])
  dataset = Flowers102('data/flower_data', transform=transform, split='train', download=True)
  dataloader = DataLoader(dataset, batch_size=batch_size)
  return dataloader

# %%
flowerdata(64)
# Out:
# ...
#   0%|          | 0/344862509 [00:00<?, ?it/s]
# Extracting data/flower_data/flowers-102/102flowers.tgz to data/flower_data/flowers-102
# ...
#   0%|          | 0/14989 [00:00<?, ?it/s]

# %%
#!stylegan2_pytorch --data /content/data/flower_data/flowers-102/jpg --image-size 32 --num-train-steps 100000 --results_dir /content/drive/MyDrive/StyleGAN_Oxford_Gen --models_dir /content/drive/MyDrive/StyleGAN_oxford_Checkpoint

# %%
# !stylegan2_pytorch --data /content/data/flower_data/flowers-102/jpg --image-size 32 --calculate-fid-every 10000 --num-train-steps 62000 --results_dir /content/drive/MyDrive/StyleGAN_Oxford_Gen --models_dir /content/drive/MyDrive/StyleGAN_oxford_Checkpoint
# Out:
# continuing from previous epoch - 60
# loading from version 1.8.9
# default</content/data/flower_data/flowers-102/jpg>:  97% 60000/62000 [00:00<?, ?it/s]
# calculating FID - saving generated:   0% 0/2560 [00:00<?, ?it/s]
# calculating FID - saving generated:   0% 5/2560 [00:00<00:55, 45.82it/s]
# calculating FID - saving generated:   0% 10/2560 [00:00<00:54, 46.46it/s]
# calculating FID - saving generated:   1% 15/2560 [00:00<00:54, 46.51it/s]
# calculating FID - saving generated:   1% 20/2560 [00:00<00:54, 46.59it/s]
# calculating FID - saving generated:   1% 25/2560 [00:00<00:54, 46.38it/s]
# calculating FID - saving generated:   1% 30/2560 [00:00<00:54, 46.46it/s]
# calculating FID - saving generated:   1% 35/2560 [00:00<00:54, 46.54it/s]
# calculating FID - saving generated:   2% 40/2560 [00:00<00:54, 46.49it/s]
# calculating FID - saving generated:   2% 45/2560 [00:00<00:54, 46.41it/s]
# calculating FID - saving generated:   2% 50/2560 [00:01<00:53, 46.58it/s]
# ...
